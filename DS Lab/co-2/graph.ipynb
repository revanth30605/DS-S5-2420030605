# %%
#scatter plot for csv 
import matplotlib.pyplot as plt
import pandas as pd
df=pd.read_csv('temporal.csv')
plt.scatter(df['deep learning'], df['machine learning'], color='turquoise', marker='*')   
plt.title('Scatter Plot')
plt.xlabel('Deep Learning') 
plt.ylabel('Machine Learning')
plt.grid()
plt.show()

# %%
#using csv files to plot graphs
import matplotlib.pyplot as plt
import pandas as pd
df=pd.read_csv('temporal.csv')
plt.bar(df['deep learning'], df['machine learning'], color='pink')
plt.xlabel('Deep Learning')
plt.ylabel('Machine Learning')      
plt.show()

# %%
#adjusting bar width and color
import matplotlib.pyplot as plt
values=[5, 6, 3, 6, 2]
names=['A','B','C','D','E'] 
c1=['pink','turquoise']
c2=['pink','turquoise']
plt.bar(names, values, color=c1, width=0.5)
plt.show()
plt.barh(names, values, color=c2, height=0.5)
plt.show()

# %%
#bar graphs for categorical data horizontally
import matplotlib.pyplot as plt
values=[5, 6, 3, 6, 2]
names=['A','B','C','D','E']
plt.barh(names, values, color='pink')
plt.title('Bar Graph')
plt.xlabel('Categories')
plt.ylabel('Values')
plt.show()

# %%
#bar graphs for categorical data
import matplotlib.pyplot as plt
values=[5, 6, 3, 6, 2]
names=['A','B','C','D','E']
plt.bar(names, values, color='turquoise')
plt.title('Bar Graph')
plt.xlabel('Categories')
plt.ylabel('Values')
plt.show()

# %%
#scatter plot of the data using different colors and markers

import matplotlib.pyplot as plt
x_values=[0,1,2,3,4,5]
y_values=[0,1,4,9,16,25]
plt.scatter(x_values, y_values, color='red', marker='*')
plt.title('Scatter Plot')
plt.xlabel('X Values')
plt.ylabel('Y Values')
plt.grid()
plt.show()

# %%
#scatter plot of the data using different colors and markers

import matplotlib.pyplot as plt
x_values=[0,1,2,3,4,5]
y_values=[0,1,4,9,16,25]
plt.scatter(x_values, y_values, color='red', marker='^')
plt.title('Scatter Plot')
plt.xlabel('X Values')
plt.ylabel('Y Values')
plt.show()

# %%
#scatter plot of the data
import matplotlib.pyplot as plt
x_values=[0,1,2,3,4,5]
y_values=[0,1,4,9,16,25]
plt.scatter(x_values, y_values, color='yellow')
plt.title('Scatter Plot')
plt.xlabel('X Values')
plt.ylabel('Y Values')
plt.show()

# %%
# using limits to set the x and y axis range
import matplotlib.pyplot as plt
import pandas as pd
df = pd.read_csv('temporal.csv')
plt.plot(df['deep learning'], df['machine learning'],color='red')
plt.xlabel('Deep Learning')
plt.ylabel('Machine Learning')
plt.title('line plot')
plt.xlim(10, 100)
plt.ylim(0, 50)
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv("temporal.csv")

plt.plot(df['Mes'], df['data science'], label='data science')
plt.plot(df['Mes'], df['machine learning'], label='machine learning')
plt.plot(df['Mes'], df['deep learning'], label='deep learning')

plt.xlabel('Date')
plt.ylabel('Popularity')

plt.title('Popularity of AI terms by date')

plt.grid(True)
plt.legend()

plt.show()

# %%
# ex 7 - using csv file

import matplotlib.pyplot as plt
import pandas as pd
df=pd.read_csv("temporal.csv")
#print(df)
plt.plot(df['deep learning'],df['machine learning'],color='red')
plt.xlabel('deep learning')
plt.ylabel('machine learning')
plt.title('line plot')
plt.savefig("c02_graph1.jpg")
plt.show()

# %%
import matplotlib.pyplot as plt

y1 = []
y2 = []

x = range(-100, 100, 10)

for i in x:
    y1.append(i**2)

for i in x:
    y2.append(-i**2)

plt.plot(x, y1, color='green')
plt.plot(x, y2, color='Maroon')

plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('simple graph')

plt.axhline(color='red')
plt.axvline(color='green')

plt.savefig("co_2_graph.jpg")
plt.grid(True)

plt.show()

# %%
#COLORS FOR LINES

import matplotlib.pyplot as py
y1=[]
y2=[]
x=range(-100,100,10)
for i in x:
    y1.append(i**2)
for i in x:
    y2.append(-i**2)
plt.plot(x,y1,color='green')
plt.plot(x,y2,color='Maroon')
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('simple graph')
plt.axhline(color= 'red')
plt.axvline(color = 'green')     
plt.grid(True)
plt.show()

# %%
#both -ve and +ve values

import matplotlib.pyplot as plt
y1=[]
y2=[]
x = range(-100,100,10)
for i in x:
    y1.append(i**2)
for i in x:
    y2.append(-i**2)
plt.plot(x,y1)
plt.plot(x,y2)
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('simple graph')
plt.axhline()
plt.axvline()
plt.show()

# %%
import matplotlib.pyplot as plt
x = [11,21,13,14,51]
y = [2,4,6,8,10]
plt.title("Line Graph")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.axhline()
plt.axvline()
plt.plot(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
x = [1,2,3,4,5]
y = [2,4,6,8,10]
plt.plot(x,y)
plt.show()
# Out:
# Matplotlib is building the font cache; this may take a moment.
