# %%
import scipy as s
from scipy.stats import kurtosis
data = [10,25,14,26,35,45,67,90,40,50,60,10,16,18,20]
s.stats.skew(data,axis=0, bias=True)
kurtosis(data, axis=0, bias=True)
# Out:
# np.float64(-0.05281076796516482)

# %%
import scipy as s
from scipy.stats import kurtosis
import numpy as np
import pandas as pd
df = pd.read_csv("temporal.csv")
kurtosis(df['data science'], axis=0, bias=True)
# Out:
# np.float64(1.6481461956660963)

# %%
import pandas as pd
from sklearn.datasets import load_iris

iris = load_iris()
df = pd.DataFrame(iris.data, columns=iris.feature_names)

print("First 5 rows of dataset:")
print(df.head())
#skewness (asymmetry distribution) 
skewness_values = df.skew()
print("\nSkewness values:")
print(skewness_values)
#kurtosis (peakness/tail heaviness) 
kurtosis_values = df.kurt()
print("\nKurtosis values:")
print(kurtosis_values)
# Out:
# First 5 rows of dataset:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
# Skewness values:
# sepal length (cm)    0.314911
# sepal width (cm)     0.318966
# petal length (cm)   -0.274884
# petal width (cm)    -0.102967
# dtype: float64
#
# Kurtosis values:
# sepal length (cm)   -0.552064
# sepal width (cm)     0.228249
# petal length (cm)   -1.402103
# petal width (cm)    -1.340604
# dtype: float64

# %%
#MEAN MODE MEDIAN SD FOR TIPS DATASET
import pandas as pd
import seaborn as sns

tips = sns.load_dataset("tips")

df = tips.select_dtypes(include="number")

print("First 5 rows of dataset:")
print(df.head())

range_values = df.max() - df.min()

print("\nRange values:")
print(range_values)

variance_values = df.var()

print("\nVariance values:")
print(variance_values)

std_values = df.std()

print("\nStandard Deviation values:")
print(std_values)

Q1 = df.quantile(0.25)

Q3 = df.quantile(0.75)

IQR = Q3 - Q1

print("\nInterquartile Range (IQR):")
print(IQR)
# Out:
# First 5 rows of dataset:
#    total_bill   tip  size
# 0       16.99  1.01     2
# 1       10.34  1.66     3
# 2       21.01  3.50     3
# 3       23.68  3.31     2
# 4       24.59  3.61     4
#
# Range values:
# total_bill    47.74
# tip            9.00
# size           5.00
# dtype: float64
#
# Variance values:
# total_bill    79.252939
# tip            1.914455
# size           0.904591
# dtype: float64
#
# Standard Deviation values:
# total_bill    8.902412
# tip           1.383638
# size          0.951100
# dtype: float64
#
# Interquartile Range (IQR):
# total_bill    10.7800
# tip            1.5625
# size           1.0000
# dtype: float64

# %%
#SKEWNESS AND KURTOSIS FOR TIPS DATASET
