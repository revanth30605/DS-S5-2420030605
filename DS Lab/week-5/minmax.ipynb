# %%
#ex 1 - min max normalization

import pandas as pd
from sklearn.preprocessing import MinMaxScaler

data=pd.DataFrame({
    'A':[10,20,30,40,50],
    'B':[5,15,25,35,45],
})
print(data)
scaler=MinMaxScaler()
normalized_data=scaler.fit_transform(data)
normalized_df=pd.DataFrame(normalized_data, columns=data.columns)
print("Normalized Data(Min-Max Scaling):")
print(normalized_df)
# Out:
#     A   B
# 0  10   5
# 1  20  15
# 2  30  25
# 3  40  35
# 4  50  45
# Normalized Data(Min-Max Scaling):
#       A     B
# 0  0.00  0.00
# 1  0.25  0.25
# 2  0.50  0.50
# 3  0.75  0.75
# 4  1.00  1.00

# %%
# standard scalar
